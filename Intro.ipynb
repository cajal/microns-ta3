# %% [markdown]
# # TA3 Segmentation Pipeline
#
# This is the pipeline for EM segmentation data.
#
# To connect, obtain your credentials on `datajoint.ninai.org`.

# %%
import numpy as np
import datajoint as dj
dj.config['database.user'] = 'dimitri'    #  change to your username
dj.config['database.host'] = 'at-database'

# %% [markdown]
# Connect to schemas `microns_ta3` and `microns_nda`

# %%
import ta3
nda = dj.create_virtual_module('nda', 'microns_nda')
# Out:
# Connecting dimitri@at-database:3306

# %%
dj.ERD(ta3) -1

# %%
ta3.Synapse()
# Out:
# *segmentation  *synapse_id    presyn       postsyn     synapse_x     synapse_y     synapse_z     syn_bbox_x1    syn_bbox_y1    syn_bbox_z1    syn_bbox_x2    syn_bbox_y2    syn_bbox_z2
# +------------+ +------------+ +----------+ +---------+ +-----------+ +-----------+ +-----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
# 1              1              20113710     129499      11299         8069          500           11285          8051           498            11311          8090           502
# 1              2              23717036     47418       11881         7833          617           11756          7763           613            11983          7910           623
# 1              3              155693       160691      12130         8167          845           12101          8155           843            12157          8180           847
# 1              4              4165907      556648      11992         7715          342           11962          7694           339            12026          7731           344
# 1              5              60613        50327       11633         7915          612           11608          7901           611            11657          7926           614
# 1              6              4209671      68592       12717         8038          991           12685          7992           986            12751          8086           996
# 1              7              215757       128075      12654         7713          461           12625          7698           455            12684          7732           465
#    ...
#  (1181196 tuples)

# %%
ta3.Mesh().progress()
# Out:
# Mesh                 Completed 1720929 of 1721148 (100.0%)   2017-10-10 13:52:56
# (219, 1721148)
